# %% [markdown]
# <a href="https://colab.research.google.com/github/Prudhvi1654/PRUDHVI/blob/main/Irs_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
text= "Machine Learning Is A Important Lessons."
text= text.lower()
print(text)
Words = nltk.word_tokenize(Lower_text)
print(Words)
# Out:
# machine learning is a important lessons.
# ['machine', 'learning', 'is', 'a', 'important', 'lessons', '.']

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

text = "Once up on a time There is a Thirsty Crow ."
text = text.lower()
words = nltk.word_tokenize(text)

stop_words = set(stopwords.words('english'))
filtered = [w for w in words if w.isalpha() and w not in stop_words]


ps = PorterStemmer()
stemmed = [ps.stem(w) for w in filtered]

print("Input text tokens:", words)
print("After Stopword Removal:", filtered)
print("After Stemmed:", stemmed)
# Out:
# Input text tokens: ['once', 'up', 'on', 'a', 'time', 'there', 'is', 'a', 'thirsty', 'crow', '.']
# After Stopword Removal: ['time', 'thirsty', 'crow']
# After Stemmed: ['time', 'thirsti', 'crow']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True
